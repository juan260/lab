# %%
P1 = plot(x^2,-2,2,figsize=5,axes=True);P1.show()
# Out:
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b92c463a9df2> in <module>()
# ----> 1 P1 = plot(x**Integer(2),-Integer(2),Integer(2),figsize=Integer(5),axes=True);P1.show()
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/misc/decorators.pyc in wrapper(*args, **kwds)
#     471             kwds[self.name + "options"] = suboptions
#     472
# --> 473             return func(*args, **kwds)
#     474
#     475         #Add the options specified by @options to the signature of the wrapped
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/plot/graphics.pyc in show(self, filename, linkmode, **kwds)
#    2031         from sage.repl.rich_output import get_display_manager
#    2032         dm = get_display_manager()
# -> 2033         dm.display_immediately(self, **kwds)
#    2034
#    2035     def xmin(self, xmin=None):
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/repl/rich_output/display_manager.pyc in display_immediately(self, obj, **rich_repr_kwds)
#     789             1/2
#     790         """
# --> 791         plain_text, rich_output = self._rich_output_formatter(obj, rich_repr_kwds)
#     792         self._backend.display_immediately(plain_text, rich_output)
#     793
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/repl/rich_output/display_manager.pyc in _rich_output_formatter(self, obj, rich_repr_kwds)
#     621         has_rich_repr = isinstance(obj, SageObject) and hasattr(obj, '_rich_repr_')
#     622         if has_rich_repr:
# --> 623             rich_output = self._call_rich_repr(obj, rich_repr_kwds)
#     624         if isinstance(rich_output, OutputPlainText):
#     625             plain_text = rich_output
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/repl/rich_output/display_manager.pyc in _call_rich_repr(self, obj, rich_repr_kwds)
#     579         if rich_repr_kwds:
#     580             # do not ignore errors from invalid options
# --> 581             return obj._rich_repr_(self, **rich_repr_kwds)
#     582         try:
#     583             return obj._rich_repr_(self)
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/plot/graphics.pyc in _rich_repr_(self, display_manager, **kwds)
#     906             if output_container in display_manager.supported_output():
#     907                 return display_manager.graphics_from_save(
# --> 908                     self.save, kwds, file_ext, output_container)
#     909
#     910     def __str__(self):
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/repl/rich_output/display_manager.pyc in graphics_from_save(self, save_function, save_kwds, file_extension, output_container, figsize, dpi)
#     709         if dpi is not None:
#     710             kwds['dpi'] = dpi
# --> 711         save_function(filename, **kwds)
#     712         from sage.repl.rich_output.buffer import OutputBuffer
#     713         buf = OutputBuffer.from_file(filename)
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/misc/decorators.pyc in wrapper(*args, **kwds)
#     471             kwds[self.name + "options"] = suboptions
#     472
# --> 473             return func(*args, **kwds)
#     474
#     475         #Add the options specified by @options to the signature of the wrapped
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/plot/graphics.pyc in save(self, filename, **kwds)
#    3189             rc_backup = (rcParams['ps.useafm'], rcParams['pdf.use14corefonts'],
#    3190                          rcParams['text.usetex']) # save the rcParams
# -> 3191             figure = self.matplotlib(**options)
#    3192             # You can output in PNG, PS, EPS, PDF, PGF, or SVG format, depending
#    3193             # on the file extension.
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/plot/graphics.pyc in matplotlib(self, filename, xmin, xmax, ymin, ymax, figsize, figure, sub, axes, axes_labels, axes_labels_size, fontsize, frame, verify, aspect_ratio, gridlines, gridlinesstyle, vgridlinesstyle, hgridlinesstyle, show_legend, legend_options, axes_pad, ticks_integer, tick_formatter, ticks, title, title_pos, base, scale, typeset)
#    2582             axes = self._show_axes
#    2583
# -> 2584         from matplotlib.figure import Figure
#    2585         from matplotlib import rcParams
#    2586         if typeset == 'type1': # Requires LaTeX, dvipng, gs to be installed.
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/figure.py in <module>()
#      36 from matplotlib.image import FigureImage
#      37
# ---> 38 import matplotlib.colorbar as cbar
#      39
#      40 from matplotlib.axes import Axes, SubplotBase, subplot_class_factory
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/colorbar.py in <module>()
#      32 import matplotlib.artist as martist
#      33 import matplotlib.cbook as cbook
# ---> 34 import matplotlib.collections as collections
#      35 import matplotlib.colors as colors
#      36 import matplotlib.contour as contour
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/collections.py in <module>()
#      25 import matplotlib.artist as artist
#      26 from matplotlib.artist import allow_rasterization
# ---> 27 import matplotlib.backend_bases as backend_bases
#      28 import matplotlib.path as mpath
#      29 from matplotlib import _path
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/backend_bases.py in <module>()
#      60
#      61 import matplotlib.tight_bbox as tight_bbox
# ---> 62 import matplotlib.textpath as textpath
#      63 from matplotlib.path import Path
#      64 from matplotlib.cbook import mplDeprecation, warn_deprecated
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/textpath.py in <module>()
#      13 from matplotlib.path import Path
#      14 from matplotlib import rcParams
# ---> 15 import matplotlib.font_manager as font_manager
#      16 from matplotlib.ft2font import FT2Font, KERNING_DEFAULT, LOAD_NO_HINTING
#      17 from matplotlib.ft2font import LOAD_TARGET_LIGHT
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/font_manager.py in <module>()
#    1419                 verbose.report("Using fontManager instance from %s" % _fmcache)
#    1420         except:
# -> 1421             _rebuild()
#    1422     else:
#    1423         _rebuild()
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/font_manager.py in _rebuild()
#    1404     def _rebuild():
#    1405         global fontManager
# -> 1406         fontManager = FontManager()
#    1407         if _fmcache:
#    1408             pickle_dump(fontManager, _fmcache)
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/font_manager.py in __init__(self, size, weight)
#    1057             self.defaultFont['ttf'] = self.ttffiles[0]
#    1058
# -> 1059         self.ttflist = createFontList(self.ttffiles)
#    1060
#    1061         self.afmfiles = findSystemFonts(paths, fontext='afm') + \
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/font_manager.py in createFontList(fontfiles, fontext)
#     579         else:
#     580             try:
# --> 581                 font = ft2font.FT2Font(fpath)
#     582             except RuntimeError:
#     583                 verbose.report("Could not open font file %s"%fpath)
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt (build/src/cysignals/signals.c:2438)()
#
# src/cysignals/signals.pyx in cysignals.signals.sig_raise_exception (build/src/cysignals/signals.c:1125)()
#
# KeyboardInterrupt:

# %%
# %time
var('x y')
L = [P1+point((0,a*0.01),axes=True)+plot(0.5,-2,2,color='red',axes=True)+implicit_plot(x^2+(y-a*0.01)^2-(a*0.01-0.25),(x,-2,2),(y,0,4),axes=True) for a in srange(0,300)]
A0 = animate(L)
A0.save('parabola-disco.gif')
