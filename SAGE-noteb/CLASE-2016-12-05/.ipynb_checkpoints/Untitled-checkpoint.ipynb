# %%
def F(n):
    return RR(factorial(n)/((n**n)*(e**(-n))))

# %%
F(100000)
# Out:
# 792.666120076027

# %%
L=[]
L2=[]
for i in srange(1, 1000):
    L.append((i,(F(i))))
    L2.append(L[i][1])

# %%
point(L)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_fit(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4429d83ea6f9> in <module>()
# ----> 1 find_fit(L)
#
# /usr/local/SageMath/src/sage/misc/lazy_import.pyx in sage.misc.lazy_import.LazyImport.__call__ (/usr/local/SageMath/src/build/cythonized/sage/misc/lazy_import.c:3636)()
#     384             True
#     385         """
# --> 386         return self._get_object()(*args, **kwds)
#     387
#     388     def __repr__(self):
#
# TypeError: find_fit() takes at least 2 arguments (1 given)
