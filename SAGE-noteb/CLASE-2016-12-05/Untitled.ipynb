# %%
def F(n):
    return RR(factorial(n)/((n**n)*(e**(-n))))

# %%
F(100000)
# Out:
# 792.666120076027

# %%
L=[]
L2=[]
for i in srange(1, 1000):
    L.append((i,(F(i))))
    L2.append(L[i-1][1])

# %%
point(L)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('a')
model(x)=(a*x)**(1/2)
find_fit(L, model)
# Out:
# [a == 6.285280428004861]

# %%
Numero = QQ(N(sum([floor(n*tanh(pi))/10**n for n in srange(1, 5000)]), digits=300))
Numero*=10**1000
Entero = NN(floor(Numero))
L=[]
for i in srange(0, 500):
    L.append((i, (Entero.digits())[i]==(floor((10**1000)/81).digits())[i]))
    print((Entero.digits())[i], (floor((10**1000)/81).digits())[i])
# Out:
# (8, 0)
# (1, 9)
# (2, 7)
# (9, 6)
# (4, 5)
# (8, 4)
# (0, 3)
# (1, 2)
# (7, 1)
# (1, 0)
# (1, 9)
# (9, 7)
# (9, 6)
# (3, 5)
# (8, 4)
# (5, 3)
# (4, 2)
# (5, 1)
# (4, 0)
# (7, 9)
# (6, 7)
# (2, 6)
# (7, 5)
# (2, 4)
# (5, 3)
# (3, 2)
# (6, 1)
# (0, 0)
# (6, 9)
# (5, 7)
# (3, 6)
# (5, 5)
# (5, 4)
# (4, 3)
# (6, 2)
# (4, 1)
# (8, 0)
# (1, 9)
# (0, 7)
# (8, 6)
# (7, 5)
# (5, 4)
# (8, 3)
# (1, 2)
# (0, 1)
# (0, 0)
# (6, 9)
# (3, 7)
# (4, 6)
# (9, 5)
# (0, 4)
# (9, 3)
# (7, 2)
# (7, 1)
# (8, 0)
# (8, 9)
# (2, 7)
# (9, 6)
# (4, 5)
# (1, 4)
# (8, 3)
# (0, 2)
# (9, 1)
# (4, 0)
# (3, 9)
# (2, 7)
# (8, 6)
# (3, 5)
# (8, 4)
# (8, 3)
# (8, 2)
# (8, 1)
# (1, 0)
# (5, 9)
# (5, 7)
# (0, 6)
# (4, 5)
# (2, 4)
# (5, 3)
# (6, 2)
# (4, 1)
# (1, 0)
# (8, 9)
# (5, 7)
# (1, 6)
# (6, 5)
# (6, 4)
# (4, 3)
# (7, 2)
# (4, 1)
# (5, 0)
# (3, 9)
# (9, 7)
# (4, 6)
# (8, 5)
# (1, 4)
# (9, 3)
# (3, 2)
# (8, 1)
# (1, 0)
# (2, 9)
# (4, 7)
# (3, 6)
# (1, 5)
# (1, 4)
# (1, 3)
# (5, 2)
# (3, 1)
# (6, 0)
# (7, 9)
# (3, 7)
# ...

# %%
print(L)
# Out:
# [(0, False), (1, False), (2, False), (3, False), (4, False), (5, False), (6, False), (7, False), (8, False), (9, False), (10, False), (11, False), (12, False), (13, False), (14, False), (15, False), (16, False), (17, False), (18, False), (19, False), (20, False), (21, False), (22, False), (23, False), (24, False), (25, False), (26, False), (27, True), (28, False), (29, False), (30, False), (31, True), (32, False), (33, False), (34, False), (35, False), (36, False), (37, False), (38, False), (39, False), (40, False), (41, False), (42, False), (43, False), (44, False), (45, True), (46, False), (47, False), (48, False), (49, False), (50, False), (51, False), (52, False), (53, False), (54, False), (55, False), (56, False), (57, False), (58, False), (59, False), (60, False), (61, False), (62, False), (63, False), (64, False), (65, False), (66, False), (67, False), (68, False), (69, False), (70, False), (71, False), (72, False), (73, False), (74, False), (75, False), (76, False), (77, Fals
# ...
