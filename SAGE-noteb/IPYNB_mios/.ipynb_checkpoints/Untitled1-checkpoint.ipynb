# %%
def Collatz(n):
    if n==0:
        return 0
    if n%2==0:
        return n/2
    else:
        return 3*n+1
n=100
while n!=1:
    n=Collatz(n)
    print n
# Out:
# 50
# 25
# 76
# 38
# 19
# 58
# 29
# 88
# 44
# 22
# 11
# 34
# 17
# 52
# 26
# 13
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# a) Define una funcion ordenar(L) que devuelva la lista L ordenada y utilice el algoritmo propuesto. Comprueba que
# realmente ordena una lista de longitud 20 formada por enteros aleatorios del intervalo [−100, 100].

# %%
def ordenar(L):
    L1=[]
    L2=[]
    L3=[]
    if len(L)<2:
        return L
    for i in srange(1, len(L)):
        if L[i]<L[0]:
            L1.append(L[i])
        elif L[i]>L[0]:
            L2.append(L[i])
        else:
            L3.append(L[i])
        
        M1=ordenar(L1)
        M2=ordenar(L2)
        return M1+L3+M2
    
ordenar(srange(1, 4))
# Out:
# [2]

# %% [markdown]
# 6. Dado un entero, que escribimos en la forma N = 10 · x + y con y la cifra de las unidades, definimos F (N ) := x − 2 · y.
# a) Demuestra que N es m ́ultiplo de 7 si y solo si F (N) lo es.
# b) Estudia las  ́orbitas de F en el conjunto de los enteros positivos, tratando de enunciar un criterio de divisibilidad
# de N entre 7 en terminos de la  ́orbita de N mediante F.

# %%
for x in srange(2, 100): 
    for y in srange(2, 100):
        def F(n):
            return x-2*y
        n=10*x+y
        if n%7 == 0 and not(n==0 or F(n)==0):
            print (F(n)), "          ", (n)
# Out:
# -14            28
# -28            35
# -42            42
# -56            49
# -70            56
# -84            63
# -98            70
# -112            77
# -126            84
# -140            91
# -154            98
# -168            105
# -182            112
# -196            119
# -7            35
# -21            42
# -35            49
# -49            56
# -63            63
# -77            70
# -91            77
# -105            84
# -119            91
# -133            98
# -147            105
# -161            112
# -175            119
# -189            126
# -14            49
# -28            56
# -42            63
# -56            70
# -70            77
# -84            84
# -98            91
# -112            98
# -126            105
# -140            112
# -154            119
# -168            126
# -182            133
# -7            56
# -21            63
# -35            70
# -49            77
# -63            84
# -77            91
# -91            98
# ...

# %% [markdown]
# 2. Un par de enteros primos se dicen “gemelos” si difieren en 2 unidades. Definir una funcion de n que devuelve una lista de todos los pares de primos gemelos menores que n.

# %%
def funcion(n):
    L=[]
    i=2
    while i<n:
        if is_prime(i-2):
                L.append((i-2,i))
        i=next_prime(i)        

    return L

print funcion(1000);
# Out:
# [(3, 5), (5, 7), (11, 13), (17, 19), (29, 31), (41, 43), (59, 61), (71, 73), (101, 103), (107, 109), (137, 139), (149, 151), (179, 181), (191, 193), (197, 199), (227, 229), (239, 241), (269, 271), (281, 283), (311, 313), (347, 349), (419, 421), (431, 433), (461, 463), (521, 523), (569, 571), (599, 601), (617, 619), (641, 643), (659, 661), (809, 811), (821, 823), (827, 829), (857, 859), (881, 883)]

# %% [markdown]
# 1. En una hoja de Sage define p=nth prime(2013), y escribe un programa para calcular el conjunto formado por los enteros
# n [a] con [a] recorriendo los elementos no nulos de Z p .
