# %%
var ('a b x')
p(a,b,x)=x**4-6*x**2+a*x+b
for i in srange(0,11):
    for j in srange(0,11):
        print(i, j)
        print(solve(p(a=i, b=j),x))
# Out:
# (0, 0)
# [
# x == -sqrt(6),
# x == sqrt(6),
# x == 0
# ]
# (0, 1)
# [
# x == -sqrt(2*sqrt(2) + 3),
# x == sqrt(2*sqrt(2) + 3),
# x == -sqrt(-2*sqrt(2) + 3),
# x == sqrt(-2*sqrt(2) + 3)
# ]
# (0, 2)
# [
# x == -sqrt(sqrt(7) + 3),
# x == sqrt(sqrt(7) + 3),
# x == -sqrt(-sqrt(7) + 3),
# x == sqrt(-sqrt(7) + 3)
# ]
# (0, 3)
# [
# x == -sqrt(sqrt(6) + 3),
# x == sqrt(sqrt(6) + 3),
# x == -sqrt(-sqrt(6) + 3),
# x == sqrt(-sqrt(6) + 3)
# ]
# (0, 4)
# [
# x == -sqrt(sqrt(5) + 3),
# x == sqrt(sqrt(5) + 3),
# x == -sqrt(-sqrt(5) + 3),
# x == sqrt(-sqrt(5) + 3)
# ]
# (0, 5)
# [
# x == -sqrt(5),
# x == sqrt(5),
# x == -1,
# x == 1
# ]
# (0, 6)
# [
# x == -sqrt(sqrt(3) + 3),
# x == sqrt(sqrt(3) + 3),
# x == -sqrt(-sqrt(3) + 3),
# x == sqrt(-sqrt(3) + 3)
# ]
# (0, 7)
# [
# x == -sqrt(sqrt(2) + 3),
# x == sqrt(sqrt(2) + 3),
# x == -sqrt(-sqrt(2) + 3),
# x == sqrt(-sqrt(2) + 3)
# ]
# (0, 8)
# [
# x == -sqrt(2),
# x == sqrt(2),
# x == -2,
# x == 2
# ]
# (0, 9)
# [
# x == -sqrt(3),
# x == sqrt(3)
# ]
# ...

# %%
a=0
b=0
plot(p,x,(x,0,10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-39fc502fb539> in <module>()
#       1 a=Integer(0)
#       2 b=Integer(0)
# ----> 3 plot(p,x,(x,Integer(0),Integer(10)))
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/misc/decorators.pyc in wrapper(*args, **kwds)
#     710                     kwds[new_name] = kwds[old_name]
#     711                     del kwds[old_name]
# --> 712             return func(*args, **kwds)
#     713
#     714         return wrapper
#
# /usr/local/SageMath/local/lib/python2.7/site-packages/sage/misc/decorators.pyc in wrapper(*args, **kwds)
#     552                 options['__original_opts'] = kwds
#     553             options.update(kwds)
# --> 554             return func(*args, **options)
#     555
#     556         #Add the options specified by @options to the signature of the wrapped
#
# ...
